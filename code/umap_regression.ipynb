# %%
import numpy as np
import pandas as pd
from statistics import mean
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# Set the path to the Excel sheets containing UMAP test set accuracies
mushroom_path = 'assets/UMAP/Mushroom.xlsx'
digits_path = 'assets/UMAP/Digits.xlsx'
forest_path = 'assets/UMAP/Forest.xlsx'
car_path = 'assets/UMAP/Car.xlsx'

# %%
# Set the variable for the number of neighbours used for each experiment
n_neighbours = ['3', '5', '10', '25', '35', '45']

# %%
# Create a dictionary containing number of neighbours as the key and the test set
# accuracy for UMAP with that number of neighbours as the value
mushroom_dataframes = {}
for n in n_neighbours:
    mushroom_dataframes[n] = pd.read_excel(mushroom_path, sheet_name=n)

# %%
# Test dictionary by viewing UMAP results with number of neighbours = 45
mushroom_dataframes['45']
# Out:
#    Dimensionality  Accuracy [Z, ZZ]  Accuracy [‘ZZ’]  Accuracy [‘Z’]
# 0               2              0.85             0.62            0.79  \
# 1               3              0.81             0.68            0.79
# 2               4              0.87             0.87            0.79
# 3               5              0.74             0.77            0.96
# 4               6              0.83             0.87            0.85
# 5               7              0.83             0.89            0.96
#
#    Accuracy [Y, YY]  Accuracy RBF
# 0              0.62          0.79
# 1              0.40          0.85
# 2              0.32          0.91
# 3              0.49          0.96
# 4              0.51          0.91
# 5              0.66          0.96

# %%
# Create a dictionary containing number of neighbours as the key and the test set
# accuracy for UMAP with that number of neighbours as the value
digits_dataframes = {}
for n in n_neighbours:
    digits_dataframes[n] = pd.read_excel(digits_path, sheet_name=n)

# %%
# Create a dictionary containing number of neighbours as the key and the test set
# accuracy for UMAP with that number of neighbours as the value
forest_dataframes = {}
for n in n_neighbours:
    forest_dataframes[n] = pd.read_excel(forest_path, sheet_name=n)

# %%
# Create a dictionary containing number of neighbours as the key and the test set
# accuracy for UMAP with that number of neighbours as the value
car_dataframes = {}
for n in n_neighbours:
    car_dataframes[n] = pd.read_excel(car_path, sheet_name=n)

# %% [markdown]
# ## Regression Analysis

# %% [markdown]
# #### Car Evaluation Dataset

# %%
# Iterate over the dataframes containing the UMAP results for each different
# number of neighbours value
for neighbours, df in car_dataframes.items():
    # Remove nan row for concat
    df.drop(df.tail(1).index,inplace=True)
    # Set the neighbours value to be an integer instead of a string for regression
    df['Neighbours'] = int(neighbours)

# Concat the dataframes for different number of neighbours values into one dataframe

reg_df_car = pd.concat(car_dataframes.values(), ignore_index=True, axis=0)
reg_df_car
# Out:
#     Dimensionality  Accuracy [Z, ZZ]  Accuracy [‘ZZ’]  Accuracy [‘Z’]
# 0                2              0.71             0.57            0.69  \
# 1                3              0.76             0.71            0.55
# 2                4              0.71             0.71            0.67
# 3                5              0.71             0.74            0.64
# 4                6              0.74             0.79            0.74
# 5                2              0.64             0.55            0.74
# 6                3              0.76             0.76            0.74
# 7                4              0.67             0.76            0.69
# 8                5              0.81             0.71            0.81
# 9                6              0.81             0.81            0.76
# 10               2              0.74             0.57            0.67
# 11               3              0.62             0.40            0.76
# 12               4              0.81             0.69            0.69
# 13               5              0.62             0.71            0.81
# 14               6              0.62             0.74            0.71
# 15               2              0.45             0.43            0.57
# 16               3              0.48             0.52            0.76
# 17               4              0.50             0.43            0.74
# 18               5              0.48             0.45            0.71
# 19               6              0.64             0.50            0.83
# 20               2              0.52             0.45            0.62
# 21               3              0.64             0.55            0.71
# 22               4              0.48             0.52            0.71
# 23               5              0.50             0.71            0.74
# 24               6              0.55             0.55            0.76
# 25               2              0.52             0.50            0.50
# 26               3              0.62             0.50            0.81
# 27               4              0.50             0.55            0.76
# 28               5              0.50             0.62            0.74
# 29               6              0.38             0.52            0.71
#
#     Accuracy [Y, YY]  Accuracy RBF  Neighbours
# 0               0.64          0.71           3
# 1               0.60          0.79           3
# 2               0.57          0.71           3
# 3               0.71          0.64           3
# 4               0.76          0.73           3
# 5               0.62          0.79           5
# 6               0.62          0.83           5
# 7               0.64          0.71           5
# 8               0.73          0.81           5
# 9               0.67          0.76           5
# 10              0.52          0.76          10
# 11              0.57          0.79          10
# 12              0.40          0.76          10
# 13              0.40          0.81          10
# 14              0.52          0.74          10
# 15              0.52          0.57          25
# 16              0.40          0.90          25
# 17              0.43          0.83          25
# 18              0.55          0.74          25
# 19              0.38          0.79          25
# 20              0.40          0.52          35
# 21              0.57          0.74          35
# 22              0.50          0.81          35
# 23              0.50          0.83          35
# 24              0.55          0.88          35
# 25              0.55          0.52          45
# 26              0.38          0.74          45
# 27              0.38          0.81          45
# 28              0.50          0.83          45
# 29              0.45          0.88          45

# %%
# Drop columns to leave only those containing feature map accuracy
fm_columns = list(reg_df_car.columns)
fm_columns.remove('Dimensionality')
fm_columns.remove('Neighbours')

# Iterate over each Pauli feature map
for column in fm_columns:
    
    # Reshape arrays + set x and y variables for regression
    y = np.array(reg_df_car[column]).reshape(-1, 1) * 100
    x =  np.array(reg_df_car[['Dimensionality', 'Neighbours']])
    x = sm.add_constant(x)
    
    # Run regression equation described in dissertation document
    smodel = sm.OLS(y, x)
    results = smodel.fit()
    print(column)
    print(results.summary())
# Out:
# Accuracy [Z, ZZ]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.583
# Method:                 Least Squares   F-statistic:                     21.25
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           2.86e-06
# Time:                        15:21:53   Log-Likelihood:                -102.92
# No. Observations:                  30   AIC:                             211.8
# Df Residuals:                      27   BIC:                             216.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         73.4451      4.706     15.607      0.000      63.790      83.101
# x1             0.1000      1.017      0.098      0.922      -1.988       2.188
# x2            -0.5957      0.091     -6.518      0.000      -0.783      -0.408
# ==============================================================================
# Omnibus:                        1.189   Durbin-Watson:                   1.561
# Prob(Omnibus):                  0.552   Jarque-Bera (JB):                0.943
# Skew:                           0.153   Prob(JB):                        0.624
# Kurtosis:                       2.187   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Accuracy [‘ZZ’]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.513
# Model:                            OLS   Adj. R-squared:                  0.477
# Method:                 Least Squares   F-statistic:                     14.21
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           6.07e-05
# Time:                        15:21:53   Log-Likelihood:                -106.72
# No. Observations:                  30   AIC:                             219.4
# Df Residuals:                      27   BIC:                             223.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         54.6843      5.340     10.240      0.000      43.727      65.641
# x1             3.6333      1.155      3.147      0.004       1.264       6.002
# x2            -0.4464      0.104     -4.304      0.000      -0.659      -0.234
# ==============================================================================
# Omnibus:                        3.891   Durbin-Watson:                   1.551
# Prob(Omnibus):                  0.143   Jarque-Bera (JB):                2.956
# Skew:                          -0.768   Prob(JB):                        0.228
# Kurtosis:                       3.062   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Accuracy [‘Z’]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.240
# Model:                            OLS   Adj. R-squared:                  0.184
# Method:                 Least Squares   F-statistic:                     4.265
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):             0.0246
# Time:                        15:21:53   Log-Likelihood:                -98.915
# No. Observations:                  30   AIC:                             203.8
# Df Residuals:                      27   BIC:                             208.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         60.7196      4.117     14.748      0.000      52.272      69.168
# x1             2.6000      0.890      2.921      0.007       0.773       4.427
# x2             0.0007      0.080      0.008      0.993      -0.163       0.165
# ==============================================================================
# Omnibus:                        1.574   Durbin-Watson:                   2.255
# Prob(Omnibus):                  0.455   Jarque-Bera (JB):                1.116
# Skew:                          -0.470   Prob(JB):                        0.572
# Kurtosis:                       2.902   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Accuracy [Y, YY]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.386
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                     8.487
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):            0.00138
# Time:                        15:21:53   Log-Likelihood:                -106.65
# No. Observations:                  30   AIC:                             219.3
# Df Residuals:                      27   BIC:                             223.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         59.3479      5.328     11.139      0.000      48.416      70.280
# x1             0.6833      1.152      0.593      0.558      -1.680       3.047
# x2            -0.4218      0.103     -4.077      0.000      -0.634      -0.210
# ==============================================================================
# Omnibus:                        1.406   Durbin-Watson:                   1.235
# Prob(Omnibus):                  0.495   Jarque-Bera (JB):                1.227
# Skew:                          -0.465   Prob(JB):                        0.542
# Kurtosis:                       2.660   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Accuracy RBF
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     3.078
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):             0.0625
# Time:                        15:21:53   Log-Likelihood:                -106.25
# No. Observations:                  30   AIC:                             218.5
# Df Residuals:                      27   BIC:                             222.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         64.2175      5.258     12.213      0.000      53.429      75.006
# x1             2.8167      1.137      2.477      0.020       0.484       5.149
# x2             0.0138      0.102      0.135      0.894      -0.196       0.223
# ==============================================================================
# Omnibus:                        2.345   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.310   Jarque-Bera (JB):                1.758
# Skew:                          -0.591   Prob(JB):                        0.415
# Kurtosis:                       2.905   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Mushroom Dataset

# %%
# Set the neighbours value to be an integer instead of a string for regression
for neighbours, df in mushroom_dataframes.items():
    df['Neighbours'] = int(neighbours)

# Concat the dataframes for different number of neighbours values into one dataframe
reg_df_mushroom = pd.concat(mushroom_dataframes.values(), ignore_index=True, axis=0)
reg_df_mushroom
# Out:
#     Dimensionality  Accuracy [Z, ZZ]  Accuracy [‘ZZ’]  Accuracy [‘Z’]
# 0                2              0.98             0.85            0.89  \
# 1                3              0.98             0.98            0.94
# 2                4              0.94             0.94            0.89
# 3                5              0.98             0.98            0.94
# 4                6              0.98             0.98            0.94
# 5                7              0.98             0.98            0.94
# 6                2              0.89             0.68            0.79
# 7                3              0.98             0.87            0.96
# 8                4              0.98             0.98            0.98
# 9                5              0.98             0.98            0.98
# 10               6              0.98             0.98            0.94
# 11               7              0.98             0.98            0.87
# 12               2              0.87             0.55            0.87
# 13               3              0.96             0.83            0.87
# 14               4              0.94             0.85            0.94
# 15               5              0.98             0.98            0.89
# 16               6              0.98             0.98            0.94
# 17               7              1.00             0.98            0.94
# 18               2              0.79             0.64            0.79
# 19               3              0.80             0.70            0.79
# 20               4              0.94             0.81            0.85
# 21               5              0.87             0.87            0.85
# 22               6              0.89             0.91            0.79
# 23               7              0.94             0.96            0.83
# 24               2              0.79             0.64            0.79
# 25               3              0.80             0.70            0.79
# 26               4              0.94             0.81            0.85
# 27               5              0.87             0.87            0.85
# 28               6              0.89             0.91            0.79
# 29               7              0.94             0.96            0.83
# 30               2              0.85             0.62            0.79
# 31               3              0.81             0.68            0.79
# 32               4              0.87             0.87            0.79
# 33               5              0.74             0.77            0.96
# 34               6              0.83             0.87            0.85
# 35               7              0.83             0.89            0.96
#
#     Accuracy [Y, YY]  Accuracy RBF  Neighbours
# 0               0.68          0.94           3
# 1               0.94          0.98           3
# 2               0.94          0.94           3
# 3               0.98          0.94           3
# 4               0.98          0.94           3
# 5               0.98          0.94           3
# 6               0.77          0.85           5
# 7               0.83          0.98           5
# 8               0.98          0.98           5
# 9               0.98          0.98           5
# 10              0.98          0.98           5
# 11              0.98          0.87           5
# 12              0.53          0.87          10
# 13              0.79          0.87          10
# 14              0.74          0.94          10
# 15              0.98          0.87          10
# 16              0.96          0.94          10
# 17              0.94          0.94          10
# 18              0.74          0.79          25
# 19              0.77          0.79          25
# 20              0.79          0.87          25
# 21              0.89          0.85          25
# 22              0.81          0.80          25
# 23              0.79          0.83          25
# 24              0.74          0.79          35
# 25              0.77          0.79          35
# 26              0.79          0.87          35
# 27              0.89          0.85          35
# 28              0.81          0.80          35
# 29              0.79          0.83          35
# 30              0.62          0.79          45
# 31              0.40          0.85          45
# 32              0.32          0.91          45
# 33              0.49          0.96          45
# 34              0.51          0.91          45
# 35              0.66          0.96          45

# %%
# Drop columns to leave only those containing feature map accuracy
fm_columns = list(reg_df_mushroom.columns)
fm_columns.remove('Dimensionality')
fm_columns.remove('Neighbours')

# Iterate over each Pauli feature map
for column in fm_columns:
    
    # Reshape arrays + set x and y variables for regression
    y = np.array(reg_df_mushroom[column]).reshape(-1, 1) * 100
    x = np.array(reg_df_mushroom[['Dimensionality', 'Neighbours']])
    x = sm.add_constant(x)
    
    # Run regression equation described in dissertation document
    smodel = sm.OLS(y, x)
    results = smodel.fit()
    print('\n', column)
    print(results.summary())
# Out:
#  Accuracy [Z, ZZ]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.710
# Model:                            OLS   Adj. R-squared:                  0.693
# Method:                 Least Squares   F-statistic:                     40.42
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           1.34e-09
# Time:                        15:21:53   Log-Likelihood:                -100.25
# No. Observations:                  36   AIC:                             206.5
# Df Residuals:                      33   BIC:                             211.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         91.9477      2.118     43.417      0.000      87.639      96.256
# x1             1.4143      0.399      3.541      0.001       0.602       2.227
# x2            -0.3580      0.043     -8.264      0.000      -0.446      -0.270
# ==============================================================================
# Omnibus:                        0.033   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.984   Jarque-Bera (JB):                0.114
# Skew:                          -0.058   Prob(JB):                        0.944
# Kurtosis:                       2.749   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [‘ZZ’]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     50.34
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           9.44e-11
# Time:                        15:21:53   Log-Likelihood:                -117.11
# No. Observations:                  36   AIC:                             240.2
# Df Residuals:                      33   BIC:                             245.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         67.7801      3.383     20.036      0.000      60.898      74.663
# x1             5.5476      0.638      8.695      0.000       4.250       6.846
# x2            -0.3466      0.069     -5.008      0.000      -0.487      -0.206
# ==============================================================================
# Omnibus:                        6.382   Durbin-Watson:                   1.321
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                6.895
# Skew:                          -0.409   Prob(JB):                       0.0318
# Kurtosis:                       4.982   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [‘Z’]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.384
# Method:                 Least Squares   F-statistic:                     11.90
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           0.000129
# Time:                        15:21:53   Log-Likelihood:                -109.34
# No. Observations:                  36   AIC:                             224.7
# Df Residuals:                      33   BIC:                             229.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         86.2240      2.726     31.631      0.000      80.678      91.770
# x1             1.3095      0.514      2.547      0.016       0.264       2.356
# x2            -0.2320      0.056     -4.160      0.000      -0.345      -0.119
# ==============================================================================
# Omnibus:                        3.035   Durbin-Watson:                   1.494
# Prob(Omnibus):                  0.219   Jarque-Bera (JB):                1.887
# Skew:                           0.517   Prob(JB):                        0.389
# Kurtosis:                       3.436   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [Y, YY]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.622
# Model:                            OLS   Adj. R-squared:                  0.599
# Method:                 Least Squares   F-statistic:                     27.15
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           1.07e-07
# Time:                        15:21:53   Log-Likelihood:                -136.29
# No. Observations:                  36   AIC:                             278.6
# Df Residuals:                      33   BIC:                             283.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         78.8799      5.763     13.688      0.000      67.156      90.604
# x1             3.6190      1.087      3.330      0.002       1.408       5.830
# x2            -0.7750      0.118     -6.574      0.000      -1.015      -0.535
# ==============================================================================
# Omnibus:                        3.315   Durbin-Watson:                   1.083
# Prob(Omnibus):                  0.191   Jarque-Bera (JB):                2.547
# Skew:                          -0.651   Prob(JB):                        0.280
# Kurtosis:                       3.054   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy RBF
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.307
# Model:                            OLS   Adj. R-squared:                  0.265
# Method:                 Least Squares   F-statistic:                     7.298
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):            0.00238
# Time:                        15:21:53   Log-Likelihood:                -112.01
# No. Observations:                  36   AIC:                             230.0
# Df Residuals:                      33   BIC:                             234.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         88.8557      2.936     30.266      0.000      82.883      94.829
# x1             0.9381      0.554      1.694      0.100      -0.188       2.065
# x2            -0.2057      0.060     -3.424      0.002      -0.328      -0.083
# ==============================================================================
# Omnibus:                        2.436   Durbin-Watson:                   0.845
# Prob(Omnibus):                  0.296   Jarque-Bera (JB):                1.470
# Skew:                           0.209   Prob(JB):                        0.480
# Kurtosis:                       2.103   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Digits Dataset

# %%
# Set the neighbours value to be an integer instead of a string for regression
for neighbours, df in digits_dataframes.items():
    df['Neighbours'] = int(neighbours)

# Concat the dataframes for different number of neighbours values into one dataframe
reg_df_digits = pd.concat(digits_dataframes.values(), ignore_index=True, axis=0)
reg_df_digits
# Out:
#     Dimensionality  Accuracy [Z, ZZ]  Accuracy [‘ZZ’]  Accuracy [‘Z’]
# 0                2              0.91             0.67            0.89  \
# 1                3              0.97             0.81            0.91
# 2                4              0.97             0.97            0.90
# 3                5              0.97             0.97            0.93
# 4                6              0.97             0.97            0.93
# 5                7              0.97             0.97            0.97
# 6                2              0.90             0.76            0.97
# 7                3              0.95             0.76            0.98
# 8                4              0.98             0.88            0.98
# 9                5              0.98             0.93            0.98
# 10               6              0.98             0.95            0.98
# 11               7              0.97             0.98            0.98
# 12               2              0.97             0.62            0.91
# 13               3              0.97             0.67            0.97
# 14               4              0.98             0.90            0.98
# 15               5              0.97             0.72            0.98
# 16               6              0.93             0.90            0.98
# 17               7              0.95             0.90            0.98
# 18               2              0.83             0.60            0.91
# 19               3              0.81             0.67            0.95
# 20               4              0.79             0.57            0.93
# 21               5              0.86             0.55            0.95
# 22               6              0.84             0.67            0.98
# 23               7              0.90             0.71            0.98
# 24               2              0.72             0.45            0.79
# 25               3              0.93             0.38            0.93
# 26               4              0.78             0.48            0.97
# 27               5              0.70             0.59            0.98
# 28               6              0.88             0.74            0.98
# 29               7              0.90             0.67            0.98
# 30               2              0.79             0.40            0.84
# 31               3              0.71             0.38            0.90
# 32               4              0.78             0.59            0.95
# 33               5              0.78             0.48            0.97
# 34               6              0.78             0.57            0.95
# 35               7              0.63             0.55            0.98
#
#     Accuracy [Y, YY]  Accuracy RBF  Neighbours
# 0               0.59          0.91           3
# 1               0.78          0.93           3
# 2               0.86          0.93           3
# 3               0.93          0.97           3
# 4               0.97          0.97           3
# 5               0.97          0.97           3
# 6               0.43          0.98           5
# 7               0.60          0.98           5
# 8               0.72          0.98           5
# 9               0.78          0.98           5
# 10              0.79          0.98           5
# 11              0.93          0.98           5
# 12              0.52          0.98          10
# 13              0.47          0.98          10
# 14              0.64          0.97          10
# 15              0.62          0.98          10
# 16              0.50          0.98          10
# 17              0.72          0.97          10
# 18              0.48          0.86          25
# 19              0.45          0.95          25
# 20              0.41          0.97          25
# 21              0.55          0.95          25
# 22              0.67          0.98          25
# 23              0.40          0.98          25
# 24              0.38          0.44          35
# 25              0.36          0.93          35
# 26              0.29          0.97          35
# 27              0.50          0.98          35
# 28              0.52          0.98          35
# 29              0.48          0.97          35
# 30              0.43          0.84          45
# 31              0.40          0.93          45
# 32              0.55          0.97          45
# 33              0.57          0.95          45
# 34              0.57          0.93          45
# 35              0.52          0.97          45

# %%
# Drop columns to leave only those containing feature map accuracy
fm_columns = list(reg_df_digits.columns)
fm_columns.remove('Dimensionality')
fm_columns.remove('Neighbours')

# Iterate over each Pauli feature map
for column in fm_columns:
    
    # Reshape arrays + set x and y variables for regression
    y = np.array(reg_df_digits[column]).reshape(-1, 1) * 100
    x = np.array(reg_df_digits[['Dimensionality', 'Neighbours']])
    x = sm.add_constant(x)
    
    # Run regression equation described in dissertation document
    smodel = sm.OLS(y, x)
    results = smodel.fit()
    print('\n', column)
    print(results.summary())
# Out:
#  Accuracy [Z, ZZ]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.736
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     46.00
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           2.86e-10
# Time:                        15:21:53   Log-Likelihood:                -109.22
# No. Observations:                  36   AIC:                             224.4
# Df Residuals:                      33   BIC:                             229.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         96.5674      2.717     35.537      0.000      91.039     102.096
# x1             0.5238      0.513      1.022      0.314      -0.519       1.567
# x2            -0.5302      0.056     -9.537      0.000      -0.643      -0.417
# ==============================================================================
# Omnibus:                        2.730   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.255   Jarque-Bera (JB):                1.694
# Skew:                          -0.158   Prob(JB):                        0.429
# Kurtosis:                       4.015   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [‘ZZ’]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     106.5
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           4.01e-15
# Time:                        15:21:53   Log-Likelihood:                -120.02
# No. Observations:                  36   AIC:                             246.0
# Df Residuals:                      33   BIC:                             250.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         69.8398      3.668     19.042      0.000      62.378      77.302
# x1             4.5905      0.692      6.636      0.000       3.183       5.998
# x2            -0.9755      0.075    -13.001      0.000      -1.128      -0.823
# ==============================================================================
# Omnibus:                        0.294   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.863   Jarque-Bera (JB):                0.479
# Skew:                           0.104   Prob(JB):                        0.787
# Kurtosis:                       2.474   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [‘Z’]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.393
# Method:                 Least Squares   F-statistic:                     12.31
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           0.000101
# Time:                        15:21:53   Log-Likelihood:                -93.948
# No. Observations:                  36   AIC:                             193.9
# Df Residuals:                      33   BIC:                             198.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         88.5930      1.778     49.836      0.000      84.976      92.210
# x1             1.6000      0.335      4.772      0.000       0.918       2.282
# x2            -0.0495      0.036     -1.362      0.182      -0.124       0.024
# ==============================================================================
# Omnibus:                       10.751   Durbin-Watson:                   1.285
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.433
# Skew:                          -1.005   Prob(JB):                      0.00543
# Kurtosis:                       4.708   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [Y, YY]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.600
# Model:                            OLS   Adj. R-squared:                  0.576
# Method:                 Least Squares   F-statistic:                     24.74
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           2.73e-07
# Time:                        15:21:53   Log-Likelihood:                -138.92
# No. Observations:                  36   AIC:                             283.8
# Df Residuals:                      33   BIC:                             288.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         54.7621      6.200      8.832      0.000      42.147      67.377
# x1             4.4333      1.169      3.791      0.001       2.054       6.813
# x2            -0.7515      0.127     -5.925      0.000      -1.010      -0.493
# ==============================================================================
# Omnibus:                        0.940   Durbin-Watson:                   1.291
# Prob(Omnibus):                  0.625   Jarque-Bera (JB):                0.962
# Skew:                          -0.337   Prob(JB):                        0.618
# Kurtosis:                       2.569   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy RBF
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.181
# Method:                 Least Squares   F-statistic:                     4.863
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):             0.0141
# Time:                        15:21:53   Log-Likelihood:                -125.99
# No. Observations:                  36   AIC:                             258.0
# Df Residuals:                      33   BIC:                             262.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         87.6618      4.329     20.252      0.000      78.855      96.468
# x1             2.1571      0.816      2.642      0.012       0.496       3.818
# x2            -0.1467      0.089     -1.657      0.107      -0.327       0.033
# ==============================================================================
# Omnibus:                       66.017   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              693.584
# Skew:                          -4.154   Prob(JB):                    2.46e-151
# Kurtosis:                      22.833   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Forest Covertype Dataset

# %%
# Set the neighbours value to be an integer instead of a string for regression
for neighbours, df in forest_dataframes.items():
    df['Neighbours'] = int(neighbours)

# Concat the dataframes for different number of neighbours values into one dataframe
reg_df_forest = pd.concat(forest_dataframes.values(), ignore_index=True, axis=0)
reg_df_forest
# Out:
#     Dimensionality  Accuracy [Z, ZZ]  Accuracy [‘ZZ’]  Accuracy [‘Z’]
# 0                2              0.66             0.42            0.71  \
# 1                3              0.65             0.68            0.66
# 2                4              0.65             0.60            0.60
# 3                5              0.68             0.69            0.66
# 4                6              0.68             0.68            0.68
# 5                7              0.65             0.66            0.63
# 6                2              0.69             0.58            0.68
# 7                3              0.65             0.66            0.60
# 8                4              0.68             0.66            0.68
# 9                5              0.66             0.68            0.65
# 10               6              0.68             0.68            0.63
# 11               7              0.66             0.66            0.65
# 12               2              0.68             0.57            0.54
# 13               3              0.65             0.65            0.60
# 14               4              0.66             0.63            0.57
# 15               5              0.68             0.69            0.66
# 16               6              0.68             0.65            0.63
# 17               7              0.63             0.66            0.65
# 18               2              0.51             0.49            0.52
# 19               3              0.69             0.69            0.67
# 20               4              0.66             0.65            0.66
# 21               5              0.62             0.69            0.71
# 22               6              0.72             0.66            0.69
# 23               7              0.63             0.63            0.65
# 24               2              0.63             0.68            0.63
# 25               3              0.63             0.60            0.60
# 26               4              0.69             0.62            0.65
# 27               5              0.62             0.66            0.65
# 28               6              0.63             0.52            0.63
# 29               7              0.68             0.57            0.65
# 30               2              0.52             0.55            0.54
# 31               3              0.66             0.58            0.66
# 32               4              0.55             0.51            0.66
# 33               5              0.57             0.49            0.68
# 34               6              0.71             0.63            0.65
# 35               7              0.58             0.63            0.66
#
#     Accuracy [Y, YY]  Accuracy RBF  Neighbours
# 0               0.54          0.66           3
# 1               0.48          0.66           3
# 2               0.69          0.69           3
# 3               0.71          0.68           3
# 4               0.65          0.66           3
# 5               0.68          0.63           3
# 6               0.52          0.63           5
# 7               0.62          0.65           5
# 8               0.68          0.69           5
# 9               0.66          0.69           5
# 10              0.68          0.65           5
# 11              0.68          0.66           5
# 12              0.58          0.68          10
# 13              0.62          0.65          10
# 14              0.58          0.65          10
# 15              0.68          0.68          10
# 16              0.62          0.65          10
# 17              0.68          0.65          10
# 18              0.46          0.69          25
# 19              0.49          0.60          25
# 20              0.51          0.69          25
# 21              0.57          0.68          25
# 22              0.65          0.69          25
# 23              0.52          0.66          25
# 24              0.62          0.65          35
# 25              0.48          0.57          35
# 26              0.65          0.69          35
# 27              0.49          0.66          35
# 28              0.55          0.63          35
# 29              0.46          0.63          35
# 30              0.45          0.58          45
# 31              0.55          0.77          45
# 32              0.49          0.66          45
# 33              0.54          0.69          45
# 34              0.54          0.66          45
# 35              0.55          0.66          45

# %%
# Drop columns to leave only those containing feature map accuracy
fm_columns = list(reg_df_forest.columns)
fm_columns.remove('Dimensionality')
fm_columns.remove('Neighbours')

# Iterate over each Pauli feature map
for column in fm_columns:
    
    # Reshape arrays + set x and y variables for regression
    y = np.array(reg_df_forest[column]).reshape(-1, 1) * 100
    x = np.array(reg_df_forest[['Dimensionality', 'Neighbours']])
    x = sm.add_constant(x)
    
    # Run regression equation described in dissertation document
    smodel = sm.OLS(y, x)
    results = smodel.fit()
    print('\n', column)
    print(results.summary())
# Out:
#  Accuracy [Z, ZZ]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     5.171
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):             0.0111
# Time:                        15:21:53   Log-Likelihood:                -102.49
# No. Observations:                  36   AIC:                             211.0
# Df Residuals:                      33   BIC:                             215.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         64.9596      2.254     28.823      0.000      60.374      69.545
# x1             0.5476      0.425      1.288      0.207      -0.317       1.412
# x2            -0.1359      0.046     -2.947      0.006      -0.230      -0.042
# ==============================================================================
# Omnibus:                        2.041   Durbin-Watson:                   2.723
# Prob(Omnibus):                  0.360   Jarque-Bera (JB):                1.001
# Skew:                          -0.302   Prob(JB):                        0.606
# Kurtosis:                       3.550   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [‘ZZ’]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                  0.185
# Method:                 Least Squares   F-statistic:                     4.967
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):             0.0130
# Time:                        15:21:53   Log-Likelihood:                -114.83
# No. Observations:                  36   AIC:                             235.7
# Df Residuals:                      33   BIC:                             240.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         59.3391      3.175     18.689      0.000      52.879      65.799
# x1             1.2905      0.599      2.155      0.039       0.072       2.509
# x2            -0.1494      0.065     -2.300      0.028      -0.282      -0.017
# ==============================================================================
# Omnibus:                       11.099   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               10.979
# Skew:                          -1.022   Prob(JB):                      0.00413
# Kurtosis:                       4.773   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [‘Z’]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     2.339
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):              0.112
# Time:                        15:21:53   Log-Likelihood:                -101.96
# No. Observations:                  36   AIC:                             209.9
# Df Residuals:                      33   BIC:                             214.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         60.0319      2.221     27.034      0.000      55.514      64.550
# x1             0.9048      0.419      2.160      0.038       0.053       1.757
# x2            -0.0050      0.045     -0.111      0.912      -0.097       0.087
# ==============================================================================
# Omnibus:                        0.638   Durbin-Watson:                   1.822
# Prob(Omnibus):                  0.727   Jarque-Bera (JB):                0.364
# Skew:                          -0.245   Prob(JB):                        0.834
# Kurtosis:                       2.954   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy [Y, YY]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.474
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     14.86
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):           2.50e-05
# Time:                        15:21:53   Log-Likelihood:                -114.05
# No. Observations:                  36   AIC:                             234.1
# Df Residuals:                      33   BIC:                             238.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         56.9490      3.107     18.329      0.000      50.628      63.270
# x1             1.6190      0.586      2.763      0.009       0.427       2.811
# x2            -0.2987      0.064     -4.699      0.000      -0.428      -0.169
# ==============================================================================
# Omnibus:                        0.164   Durbin-Watson:                   2.364
# Prob(Omnibus):                  0.921   Jarque-Bera (JB):                0.051
# Skew:                          -0.080   Prob(JB):                        0.975
# Kurtosis:                       2.906   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#  Accuracy RBF
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.058
# Method:                 Least Squares   F-statistic:                   0.03604
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):              0.965
# Time:                        15:21:53   Log-Likelihood:                -95.811
# No. Observations:                  36   AIC:                             197.6
# Df Residuals:                      33   BIC:                             202.4
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         65.9088      1.872     35.205      0.000      62.100      69.718
# x1             0.0619      0.353      0.175      0.862      -0.656       0.780
# x2            -0.0078      0.038     -0.203      0.840      -0.086       0.070
# ==============================================================================
# Omnibus:                        6.273   Durbin-Watson:                   2.391
# Prob(Omnibus):                  0.043   Jarque-Bera (JB):                8.593
# Skew:                           0.131   Prob(JB):                       0.0136
# Kurtosis:                       5.379   Cond. No.                         82.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
